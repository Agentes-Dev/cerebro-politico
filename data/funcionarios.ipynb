# %%
import pandas as pd

# %%
df = pd.read_csv('funcionarios.csv', sep=';')
df
# Out:
#           ponto  codGrupo                   grupo  \
# 0        P_5948         1    Quadro Efetivo - RJU
# 1        P_8107         1    Quadro Efetivo - RJU
# 2        P_6746         1    Quadro Efetivo - RJU
# 3        P_6833         1    Quadro Efetivo - RJU
# 4        P_6835         1    Quadro Efetivo - RJU
# ...         ...       ...                     ...
# 14487  P_263328         6  Secretário Parlamentar
# 14488  P_216690         6  Secretário Parlamentar
# 14489  P_156813         6  Secretário Parlamentar
# 14490  P_162790         6  Secretário Parlamentar
# 14491  P_277868         6  Secretário Parlamentar
#
#                                   nome  \
# 0             ABIDERMAN SOUZA CARVALHO
# 1            ABRAÃO DE CARVALHO SANTOS
# 2               ABRAÃO GONÇALVES SAIGG
# 3                ABRAHÃO REZENDE AIDAR
# 4                    ADA LIZ CAVALHERO
# ...                                ...
# 14487          ZULAMAR JUAREZ DE SOUSA
# ...
