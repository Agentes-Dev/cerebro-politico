# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ### Pegando os dataframes

# %% [markdown]
# Lista de deputados

# %%
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados'
r = requests.get(url).json()
df = pd.DataFrame(r['dados'])
df
# Out:
#          id                                                uri  \
# 0    220593  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1    204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2    220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3    221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4    204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# ..      ...                                                ...
# 508  220558  https://dadosabertos.camara.leg.br/api/v2/depu...
# 509  204517  https://dadosabertos.camara.leg.br/api/v2/depu...
# 510  160592  https://dadosabertos.camara.leg.br/api/v2/depu...
# 511  220592  https://dadosabertos.camara.leg.br/api/v2/depu...
# 512  220552  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nome  siglaPartido  \
# 0     Abilio Brunini            PL
# 1     Acácio Favacho           MDB
# 2        Adail Filho  REPUBLICANOS
# 3    Adilson Barroso            PL
# ...

# %% [markdown]
# Informações individuais deputado

# %%
url_deputado = 'https://dadosabertos.camara.leg.br/api/v2/deputados/160592'
r_deputado = requests.get(url_deputado).json()
deputado = pd.json_normalize(r_deputado['dados'])[['nomeCivil', 'cpf','sexo', 'dataNascimento', 'dataFalecimento', 'ufNascimento', 'dataFalecimento', 'ufNascimento', 'escolaridade', 'ultimoStatus.id', 'ultimoStatus.siglaPartido', 'ultimoStatus.idLegislatura', 'ultimoStatus.gabinete.telefone', 'ultimoStatus.situacao', 'ultimoStatus.condicaoEleitoral',
       'ultimoStatus.descricaoStatus']]
deputado
# Out:
#                                 nomeCivil          cpf sexo dataNascimento  \
# 0  JOSÉ CARLOS BECKER DE OLIVEIRA E SILVA  03098871946    M     1978-06-21
#
#   dataFalecimento ufNascimento dataFalecimento ufNascimento escolaridade  \
# 0            None           PR            None           PR     Superior
#
#    ultimoStatus.id ultimoStatus.siglaPartido  ultimoStatus.idLegislatura  \
# 0           160592                        PT                          57
#
#   ultimoStatus.gabinete.telefone ultimoStatus.situacao  \
# 0                      3215-5613             Exercício
#
#   ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
# 0                        Titular                         None

# %% [markdown]
# Despesas individuais

# %%
url_despesas = 'https://dadosabertos.camara.leg.br/api/v2/deputados/160592/despesas'
r_despesas = requests.get(url_despesas).json()
df_despesas = pd.DataFrame(r_despesas['dados'])
df_despesas
# Out:
#      ano  mes                                        tipoDespesa  \
# 0   2023    5  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1   2023    4  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2   2023    6  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 3   2023    7  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 4   2023    7  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 5   2023    6  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 6   2023    5  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 7   2023    5  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 8   2023    9  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 9   2023    5  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 10  2023    6                      COMBUSTÍVEIS E LUBRIFICANTES.
# 11  2023    6                      COMBUSTÍVEIS E LUBRIFICANTES.
# 12  2023    9                      COMBUSTÍVEIS E LUBRIFICANTES.
# ...

# %% [markdown]
# Eventos que participou

# %%
url_eventos = 'https://dadosabertos.camara.leg.br/api/v2/deputados/160592/eventos'
r_eventos = requests.get(url_eventos).json()
df_eventos = pd.DataFrame(r_eventos['dados'])
df_eventos.rename(columns={'descricao': 'eventos_parlamentares'}, inplace=True)
df_eventos.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Frentes Parlamentares

# %%
url_frentes = 'https://dadosabertos.camara.leg.br/api/v2/deputados/160592/frentes'
r_frentes = requests.get(url_frentes).json()
df_frentes = pd.DataFrame(r_frentes['dados'])
df_frentes.rename(columns={'titulo': 'frentes_parlamentares'}, inplace=True)
df_frentes.head()
# Out:
#       id                                                uri  \
# 0  55599  https://dadosabertos.camara.leg.br/api/v2/fren...
# 1  55575  https://dadosabertos.camara.leg.br/api/v2/fren...
# 2  55588  https://dadosabertos.camara.leg.br/api/v2/fren...
# 3  55589  https://dadosabertos.camara.leg.br/api/v2/fren...
# 4  55573  https://dadosabertos.camara.leg.br/api/v2/fren...
#
#                                frentes_parlamentares  idLegislatura
# 0    Frente Parlamentar por Doenças Crônicas de Pele             57
# 1  Frente Parlamentar Mista de Apoio ao Sistema N...             57
# 2  Frente Parlamentar em Defesa da Soberania Naci...             57
# 3  Frente Parlamentar sobre o Limite dos Juros e ...             57
# 4  Frente Parlamentar em Defesa da Arte e Cultura...             57

# %% [markdown]
# Mandatos anteriores

# %%
url_mandatosExternos = 'https://dadosabertos.camara.leg.br/api/v2/deputados/160592/mandatosExternos'
r_mandatosExternos = requests.get(url_mandatosExternos).json()
df_mandatosExternos = pd.DataFrame(r_mandatosExternos['dados'])
df_mandatosExternos.head()
# Out:
#          cargo siglaUf          municipio anoInicio anoFim  \
# 0  Prefeito(a)      PR  Cruzeiro do Oeste      2005   2008
# 1  Prefeito(a)      PR  Cruzeiro do Oeste      2009   2010
#
#   siglaPartidoEleicao                                  uriPartidoEleicao
# 0                  PT  https://dadosabertos.camara.leg.br/api/v2/part...
# 1                  PT  https://dadosabertos.camara.leg.br/api/v2/part...

# %% [markdown]
# Ocupações

# %%
url_ocupacoes = 'https://dadosabertos.camara.leg.br/api/v2/deputados/160592/ocupacoes'
r_ocupacoes = requests.get(url_ocupacoes).json()
df_ocupacoes = pd.DataFrame(r_ocupacoes['dados'])
df_ocupacoes.head()
# Out:
#                  titulo                                           entidade  \
# 0        Chefe Regional  Secretaria de Estado do Trabalho, Emprego e Pr...
# 1  Secretário Municipal                               Indústria e Comércio
# 2            Empresário                               Microsys Informática
#
#   entidadeUF entidadePais  anoInicio  anoFim
# 0         PR       BRASIL       2003    2004
# 1         PR       BRASIL       2001    2002
# 2         PR       BRASIL       1998    2003

# %% [markdown]
# Órgãos

# %%
url_orgaos = 'https://dadosabertos.camara.leg.br/api/v2/deputados/160592/orgaos'
r_orgaos = requests.get(url_orgaos).json()
df_orgaos = pd.DataFrame(r_orgaos['dados'])
df_orgaos.head()
# Out:
#    idOrgao                                           uriOrgao siglaOrgao  \
# 0     2009  https://dadosabertos.camara.leg.br/api/v2/orga...         CE
# 1   539426  https://dadosabertos.camara.leg.br/api/v2/orga...   CPIAMERI
#
#                                            nomeOrgao  \
# 0                               Comissão de Educação
# 1  Comissão Parlamentar de Inquérito destinada a ...
#
#                         nomePublicacao    titulo codTitulo        dataInicio  \
# 0                 Comissão de Educação   Titular       101  2023-03-15T00:00
# 1  CPI sobre a Empresa Americanas S.A.  Suplente       102  2023-05-17T00:00
#
#   dataFim
# 0    None
# 1    None

# %% [markdown]
# Profissões

# %%
url_profissoes = 'https://dadosabertos.camara.leg.br/api/v2/deputados/220558/profissoes'
r_profissoes = requests.get(url_profissoes).json()
df_profissoes = pd.DataFrame(r_profissoes['dados'])
df_profissoes.head()
# Out:
#            dataHora  codTipoProfissao                  titulo
# 0  2022-11-16T10:48               334  Motorista profissional
# 1  2022-11-16T10:48               506                Vendedor

# %% [markdown]
# Líderes

# %%
url_lideres = 'https://dadosabertos.camara.leg.br/api/v2/legislaturas/57/lideres'
r_lideres = requests.get(url_lideres).json()

#Criando colunas normalizadas
df_lideres = pd.DataFrame(r_lideres['dados'])
df_lideres['idParlamentar'] = df_lideres['parlamentar'].apply(lambda x: x['id'])
df_lideres['nome'] = df_lideres['parlamentar'].apply(lambda x: x['nome'])
df_lideres['siglaPartido'] = df_lideres['parlamentar'].apply(lambda x: x['siglaPartido'])
df_lideres['siglaUf'] = df_lideres['parlamentar'].apply(lambda x: x['siglaUf'])
df_lideres['idLegislatura'] = df_lideres['parlamentar'].apply(lambda x: x['idLegislatura'])
df_lideres['tipoLider'] = df_lideres['bancada'].apply(lambda x: x['tipo'])
df_lideres['tipoNome'] = df_lideres['bancada'].apply(lambda x: x['nome'])

df_lideres.drop(columns=['parlamentar', 'bancada'], inplace=True)

df_lideres
# Out:
#            titulo  dataInicio     dataFim  idParlamentar                 nome  \
# 0           Líder  2023-02-01        None         141470       José Guimarães
# 1           Líder  2023-02-01        None         220681         Fábio Macedo
# 2           Líder  2023-02-01        None         160674           Hugo Motta
# 3           Líder  2023-02-01        None         204494           Fred Costa
# 4           Líder  2023-02-01        None         160553        Antonio Brito
# 5           Líder  2023-02-01  2023-09-12         178882         André Fufuca
# 6           Líder  2023-02-01        None          72442      Felipe Carreras
# 7           Líder  2023-02-01        None         160510            Luis Tibé
# 8           Líder  2023-02-01        None         204560         Adolfo Viana
# 9           Líder  2023-02-01        None         178937       Altineu Côrtes
# 10          Líder  2023-02-01        None         178854     Elmar Nascimento
# ...

# %% [markdown]
# Teste

# %%
# Passo 1: Obter dados de deputados
deputados = []
for id_deputado in df['id']:
    url_deputado = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{id_deputado}'
    r_deputado = requests.get(url_deputado).json()
    deputado_info = pd.json_normalize(r_deputado['dados'])[['nomeCivil', 'cpf','sexo', 'dataNascimento', 'dataFalecimento', 'ufNascimento', 'escolaridade', 'ultimoStatus.id', 'ultimoStatus.siglaPartido', 'ultimoStatus.idLegislatura', 'ultimoStatus.gabinete.telefone', 'ultimoStatus.situacao', 'ultimoStatus.condicaoEleitoral',
       'ultimoStatus.descricaoStatus']]
    deputados.append(deputado_info)

# Passo 2: Obter dados de despesas de cada deputado
despesas = []
for id_deputado in df['id']:
    url_despesas = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{id_deputado}/despesas'
    r_despesas = requests.get(url_despesas).json()
    df_despesas = pd.DataFrame(r_despesas['dados'])
    df_despesas['id_deputado'] = id_deputado
    despesas.append(df_despesas)

# Passo 3: Criar o DataFrame final com informações de deputados
deputados_df = pd.concat(deputados, ignore_index=True)

df = pd.merge(df, deputados_df, left_on='id', right_on='ultimoStatus.id')

# Lista de IDs dos deputados
ids_deputados = df['id'].tolist()# Dicionários para armazenar informações

eventos_dict = {}
frentes_dict = {}
mandatos_dict = {}
ocupacoes_dict = {}
orgaos_dict = {}
profissoes_dict = {}

# Realize as requisições para cada deputado e armazene os dados nos dicionários
for id_deputado in ids_deputados:
    # Informações de Eventos Parlamentares
    url_eventos = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{id_deputado}/eventos'
    r_eventos = requests.get(url_eventos).json()
    eventos_dict[id_deputado] = r_eventos['dados']

    # Informações de Frentes Parlamentares
    url_frentes = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{id_deputado}/frentes'
    r_frentes = requests.get(url_frentes).json()
    frentes_dict[id_deputado] = r_frentes['dados']

    # Informações de Mandatos Externos
    url_mandatosExternos = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{id_deputado}/mandatosExternos'
    r_mandatosExternos = requests.get(url_mandatosExternos).json()
    mandatos_dict[id_deputado] = r_mandatosExternos['dados']

    # Informações de Ocupações
    url_ocupacoes = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{id_deputado}/ocupacoes'
    r_ocupacoes = requests.get(url_ocupacoes).json()
    ocupacoes_dict[id_deputado] = r_ocupacoes['dados']

    # Informações de Órgãos
    url_orgaos = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{id_deputado}/orgaos'
    r_orgaos = requests.get(url_orgaos).json()
    orgaos_dict[id_deputado] = r_orgaos['dados']

    # Informações de Profissões
    url_profissoes = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{id_deputado}/profissoes'
    r_profissoes = requests.get(url_profissoes).json()
    profissoes_dict[id_deputado] = r_profissoes['dados']

# Adicione as colunas ao DataFrame final
df['eventos'] = df['id'].map(eventos_dict)
df['frentes'] = df['id'].map(frentes_dict)
df['mandatos_externos'] = df['id'].map(mandatos_dict)
df['ocupacoes'] = df['id'].map(ocupacoes_dict)
df['orgaos'] = df['id'].map(orgaos_dict)
df['profissoes'] = df['id'].map(profissoes_dict)


# Passo 4: Criar o DataFrame final
despesas_df = pd.concat(despesas, ignore_index=True)

# Agora você pode combinar os DataFrames de despesas e informações do deputado com base no ID do deputado
df_final = pd.merge(df, despesas_df, left_on='id', right_on='id_deputado')

# df_final agora contém as informações dos deputados e as despesas em um único DataFrame
df_final
# Out:
#           id                                                uri  \
# 0     220593  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1     220593  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2     220593  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3     220593  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4     220593  https://dadosabertos.camara.leg.br/api/v2/depu...
# ...      ...                                                ...
# 7621  220552  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7622  220552  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7623  220552  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7624  220552  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7625  220552  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nome  siglaPartido  \
# 0     Abilio Brunini            PL
# 1     Abilio Brunini            PL
# 2     Abilio Brunini            PL
# 3     Abilio Brunini            PL
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7626 entries, 0 to 7625
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7626 non-null   int64
#  1   uri                             7626 non-null   object
#  2   nome                            7626 non-null   object
#  3   siglaPartido                    7626 non-null   object
#  4   uriPartido                      7626 non-null   object
#  5   siglaUf                         7626 non-null   object
#  6   idLegislatura                   7626 non-null   int64
#  7   urlFoto                         7626 non-null   object
#  8   email                           7626 non-null   object
#  9   nomeCivil                       7626 non-null   object
#  10  cpf                             7626 non-null   object
#  11  sexo                            7626 non-null   object
# ...
